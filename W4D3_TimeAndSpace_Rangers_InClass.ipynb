# %% [markdown]
# # Time/Space Complexity - Intro to Data Structures (User Defined)
#
# ### Topics to discuss today:
#
# <ul>
#     <li>Time and Space Complexity - What is it/How do we measure it</li>
#     <li>Asymptotic Analysis</li>
#     <li><strong>Data Structures</strong></li>
# </ul>
#
# ### Data Structures to discuss:
# - Arrays
# - Stacks
# - Queues
# - Linked Lists
#     - Singly Linked Lists
#     - Traversing A Linked List
#     - Finding a node in a linked list
#     - Adding to a linked list

# %% [markdown]
# ## Time and Space Complexity
#
# #### What is it?
#
# Time and space complexity is the measure of how much time a given action(function) will take to solve a problem. In the same fashion, we determine how much a given data structure will need in terms of memory allocation. A problem can have multiple solutions and finding the optimal solution for the problem needs to be analyzed in time and space.
#
# #### How do we measure Time and Space Complexity?
#
# In order to measure time and space complexity we use Asymptotic analysis. The reason for this is because we need a way to measure different algorithms (functions) based on the size of their inputs in a mathmatical way. For example, we could have a function that is computed as f(n) and another that is g(n^2). All things around the function staying constant, the only thing that changes is the size of the input. Below is the chart that shows the different Asymptotic analysis formats.

# %% [markdown]
# <table style="text-align:center;" class="table table-bordered">
# <tbody><tr>
# <td>constant</td>
# <td>−</td>
# <td>Ο(1)</td>
# </tr>
# <tr>
# <td>logarithmic</td>
# <td>−</td>
# <td>Ο(log n)</td>
# </tr>
# <tr>
# <td>linear</td>
# <td>−</td>
# <td>Ο(n)</td>
# </tr>
# <tr>
# <td>Linear Logarithmic</td>
# <td>−</td>
# <td>Ο(n log n)</td>
# </tr>
# <tr>
# <td>quadratic</td>
# <td>−</td>
# <td>Ο(n<sup>2</sup>)</td>
# </tr>
# <tr>
# <td>cubic</td>
# <td>−</td>
# <td>Ο(n<sup>3</sup>)</td>
# </tr>
# <tr>
# <td>polynomial</td>
# <td>−</td>
# <td>n<sup>Ο(1)</sup></td>
# </tr>
# <tr>
# <td>exponential</td>
# <td>−</td>
# <td>2<sup>Ο(n)</sup></td>
# </tr>
# </tbody></table>

# %%
#  constant time O(1)
def add_nums(num1, num2):
    return num1 + num2 # only performs one operation regardless of arguments passed in

# logarithmic O(Log n)
# breaking down a list into two parts, and consolidation the search for the target
# never iterating through the entirty of the list
# list needs to be sorted because the smaller numbers need to be to the left
# and larger numbers need to be on the right
def binary_search(array, target)
    left = 0
    right = len(array) - 1
    while left <= right:
        middle = (left + right) // 2
        potential_match = array(middle)
        if target == potential_match:
            return f"The index is....{middle}"
        elif target < potential_match:
            right = middle -1
        else:
            left = middle + 1
    return -1

#  linear time - O(n)
arr = [1,2,3,4,5]
def print_num(alist):
    for num in alist:
        print(num)
print_num(arr)


# Worst Case
# Not all lists we pass into this function are going to start with 1
# so worst case, either there is no 1 or 1 is at the back of the list
def find_num(alist):
    for num in alist:
        if num == 1:
            return "A One"

# Quadratic time O(n^2)
# nested loops
# for each iteration of the first list we have to traverse the entirety of the second list
def print_nums2(arr1,arr2):
    for num in arr1:
        for num2 in arr3:
            print(num1 + num2)
arr1 = [1,2,3,4,5,6,7,8]
arr2 = [9,10,11,12,13,14,15,16]

# Cubic O(n^3)
# triply nested linear operation
def print_nums3(arr1,arr2,arr3):
    for num1 in arr1:
        for num2 in arr2:
            for num3 in arr3:
                print(num1 + num2 + num3)
arr1 = [1,2,3,4,5,6,7,8]
arr2 = [9,10,11,12,13,14,15,16]
arr3 = [9,10,11,12,13,14,15,16]

# %% [markdown]
# ## Arrays

# %% [markdown]
# In python we benefit from the dynamic array which means the block of memory will expand as needed for the given input to the array. In traditional arrays (depending on the type of operating system) we will usually store our inputs in 4 or 8 consecutive blocks of memory. Below is a diagram of how that looks under the hood:
#
# ## Which in python looks like this:
#
#
# <br><img src="http://www.cs.emory.edu/~cheung/Courses/170/Syllabus/09/FIGS/array02x.gif" style="height:300px; width:450px;"><br>

# %% [markdown]
# ### Let's take a look at some of the time and space analysis of arrays

# %%
# indexing an Array (list)
# constant time and space
# arr[i]
# constant for both because:
# the single operation is grabbing the item at whatever index we're providing
# then we set a variable to that integar
my_list = [1,2,3,4,5]
my_num = my_list[3]

# searching through an array
# linear time O(n) and constant space O(1)
# we need to check each item in th elist to seee if the thing we're searching for is there
# constant space becasue no variables are set at all
if 1 in my_list:
    print("its here")

# copying an array
# linear time O(n) and linear space O(n)
my_list_copy = my_list[:]
empty_list = []
for num in my_list:
    empty_list.append(num)

# setting and index 
# constant time O(1) and constant space O(1)
my_list[2] = 20
print(my_list)

# %% [markdown]
# ## Stacks and Queues
#
# ** Stacks ** as the name suggests is a data structure that allows for data to follow the Last In First Out priciple(LIFO). Think of a stack of pancakes for example. To get the first pancake you would  start with the top and go down.
#
# ##### Searching through a stack will be Linear Time O(n) - Constant Space O(1)
# ##### Selecting the last item will be done in Constant Time O(1) - Constant Space O(1)
# ##### Adding to the stack should take Constant Time O(1) - Constant Space O(1)
#
# ** Queues ** are similar but in this case follow the First In First Out principle(FIFO). Think of this as a line in a black friday sale. The first person camped out for the big screen tv is the first to get it.
#
# ##### Searching through a queue will be Linear Time O(n) - Constant Space O(1)
# ##### Selecting the first item will be done in Constant Time O(1) - Constant Space O(1)
# ##### Adding to the queue should take Constant Time O(1) - Constant Space O(1)

# %%
# stacks
#  last in first out - LIFO
stack = ["Pancake1"]
print(stack)
stack.append("Pancake2")
print(stack)
stack.append("Pancake3")
print(stack)
stack.append("Pancake4")
print(stack)
print(stack.pop())
print(stack)
print(stack.pop())
print(stack)
# Out:
# ['Pancake1']
# ['Pancake1', 'Pancake2']
# ['Pancake1', 'Pancake2', 'Pancake3']
# ['Pancake1', 'Pancake2', 'Pancake3', 'Pancake4']
# Pancake4
# ['Pancake1', 'Pancake2', 'Pancake3']
# Pancake3
# ['Pancake1', 'Pancake2']

# %%
# Queues
# First in first out - FIFO
queue = ["shopper"]
print(queue)
queue.append("shopper2")
print(queue)
queue.append("shopper3")
print(queue)
queue.append("shopper4")
print(queue)
print(queue.pop(0))
print(queue)
print(queue.pop(0))
print(queue)
# Out:
# ['shopper']
# ['shopper', 'shopper2']
# ['shopper', 'shopper2', 'shopper3']
# ['shopper', 'shopper2', 'shopper3', 'shopper4']
# shopper
# ['shopper2', 'shopper3', 'shopper4']
# shopper2
# ['shopper3', 'shopper4']

# %%
from collections import deque
# stack
# first pancake in, last pancake out
stack = deque()
print(stack)
stack.appendleft("pancake1")
print(stack)
stack.appendleft("pancake2")
print(stack)
stack.appendleft("pancake3")
print(stack)
stack.appendleft("pancake4")
print(stack)
print(stack.popleft())
print(stack)
print(stack.popleft())
print(stack)
# Out:
# deque([])
# deque(['pancake1'])
# deque(['pancake2', 'pancake1'])
# deque(['pancake3', 'pancake2', 'pancake1'])
# deque(['pancake4', 'pancake3', 'pancake2', 'pancake1'])
# pancake4
# deque(['pancake3', 'pancake2', 'pancake1'])
# pancake3
# deque(['pancake2', 'pancake1'])

# %%
from collections import deque
# queue
# first shopper in, first shopper out
queue = deque()
queue.appendleft("shopper")
print(queue)
queue.appendleft("shopper2")
print(queue)
queue.appendleft("shopper3")
print(queue)
queue.appendleft("shopper4")
print(queue)

print(queue.pop())
print(queue)
print(queue.pop())
print(queue)
# Out:
# deque(['shopper'])
# deque(['shopper2', 'shopper'])
# deque(['shopper3', 'shopper2', 'shopper'])
# deque(['shopper4', 'shopper3', 'shopper2', 'shopper'])
# shopper
# deque(['shopper4', 'shopper3', 'shopper2'])
# shopper2
# deque(['shopper4', 'shopper3'])

# %% [markdown]
# # Sum of Parts Time Compelxity Exercise

# %%
#sum of parts
https://www.codewars.com/kata/5ce399e0047a45001c853c2b

# %% [markdown]
# ## Linked List (Data Structure)
#
# A linked list is created by using the node class. We create a Node object and create another class to use this node object. We pass the appropriate values thorugh the node object to point the to the next data elements.
#
# There are some advantages and disadvantages with this data structure. **Advantages** Linked Lists can save memory because they can be flexibile with memory management which saves memory. **Disadvantages** Finding or adding to the list requires traversing the entire list.

# %%
# A complete implementation of a linked list

# 2 components to the structure
# Node class
# Linked List Class
# node class

#Node class
class Node():
    def __init__(self, value):
        self.value = value
        self.next = None
        
#LinkedList class
class LinkedList():
    def __init__(self):
        self.head = None
        
    #pushOn - place item at the head of the list -- the beginning
    def pushOn(self, new_value):
        new_node = Node(new_value)
        new_node.next = self.head
        self.head = new_node
        
    #insertAfter - place a node after another in the linked list
#     def insertAfter(self, prev_node, new_value):
#         #check if the previous node exists
#         if prev_node is None:
#             print("The given node must not be empty")
#             return
#         #if the prev_node is not empty, we create a new node
#         new_node = Node(new_value)
        
#         # update the new node's next pointer to point to the prev_node's next
#         new_node.next = prev_node.next
        
#         #update pre_node's next to new_node
#         prev_node.next = new_node


    def insertKnownPosition(self, position, new_value):
        
        #creating the new node
        new_node = Node(new_value)
        
        #starting at the beginning of the linked list
        current_node = self.head
        next_node = current_node.next
        
        #traversing linked list until we get to our position we want to insert
        for i in range(position - 1):
            current_node = next_node
            next_node = current_node.next
            
        new_node.next = current_node.next
        current_node.next = new_node 
        
        
    def deleteNode(self, value):
        
        #starting at the beginningh of the linked list
        current_node = self.head
        next_node = current_node.next
        
        #traversing until we get to the node that is the same as our value
        while current_node.value != value and next_node.next:
            print(current_node.value)
            prev_node = current_node
            current_node = next_node
            next_node = current_node.next 
               
        #if we've reached the end of our linked list and value was not found
        if not next_node.next and current_node.value != value:
            return "Value does not exist"
        
        #setting the previous nodes next to the next node and delete our current node 
        prev_node.next = next_node 
        del current_node
        
        
    #append(add) a new node to the END of the linked list
    def append_(self, new_value):
        #create our new node
        new_node = Node(new_value)
        
        #Check if the linked list is empty
        #if it is, make this new node the head node(beginning of the list)
        if self.head is None:
            self.head = new_node
            
        #if not empty, traverse our linked list and append to the end
        last = self.head
        
        ##change current last to the new value, and continuously check for an empty next
        while last.next:
            last = last.next
        
        
        #change the current last node next value to point to the new value
        last.next = new_node
        
        
    #traverse - move through the linked list
    def traverse(self):
        temp = self.head
        #while temp is NOT NONE --> keep on truckin through the list until it is none
        while temp:
            print(temp.value)
            temp = temp.next
        print("end of list")

# %%
weekdays_list = LinkedList()
weekdays_list.pushOn("Monday")

weekdays_list.append_("Wednesday")
weekdays_list.insertKnownPosition(1, "Tuesday")
weekdays_list.append_("Friday")
weekdays_list.insertKnownPosition(3, "Thursday")
# weekdays_list.insertAfter(weekdays_list.head.next.next, "Thursday")
weekdays_list.pushOn("Sunday")
weekdays_list.append_("Saturday")

# %%
weekdays_list.traverse()
# Out:
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# end of list

# %%
Write function bmi that calculates body mass index (bmi = weight / height2).

if bmi <= 18.5 return "Underweight"

if bmi <= 25.0 return "Normal"

if bmi <= 30.0 return "Overweight"

if bmi > 30 return "Obese"

def bmi(weight, height):
    bmi = weight / (height ** 2)
    
    if bmi <= 18.5:
        return "Underweight"
    elif bmi <= 25.0:
        return "Normal"
    elif bmi <= 30.0:
        return "Overweight"
    else:
        return "Obese"

# I think this is constant time because when you enter a weight it goes to the correspondent weight right away and gives you your answer.

# %%
Take an array and remove every second element from the array. Always keep the first element and start removing with the next element.

def remove_every_other(my_list):
    return my_list[::2]

# This is constant becasue it is going through an array and removing the second element through out.

# %%
def parts_sums(ls):
    
    total_sum = sum(ls)
    sum_list = [total_sum]
    
    for num in ls:
        total_sum -= num
        sum_list.append(total_sum)
        
    return sum_list

parts_sums([0, 1, 3, 6, 10])

# used the class codewars to mix it up from constant since i have only done 7 and 8s but i think this one is linear since it is going through the code more than 
# once to get the sum and keeps going through till it gets to the end


# I think this weekend i am going to try and move to 7 and 6 atleast do more 7s but still feel like i need more practice with the structure of my code. I think i have a good grasp on what is going 
# on just need to be able to structure it better. 
# Thought on that?
